# %% [markdown]
# ## MATPLOTLIB EXPLORATION
# ____________________

# %% [markdown]
# ### Data Visualization
#
# #### Cars dataset
# 1. Start off by importing the cars.csv file in the jupyter notebook

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
cars = pd.read_csv('cars.csv')
cars.head()
# Out:
#    S.No              model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am
# 0     1          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1  \
# 1     2      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2     3         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3     4     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     5  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
#
#    gear  carb
# 0     4     4
# 1     4     4
# 2     4     1
# 3     3     1
# 4     3     2

# %% [markdown]
# 2. Generate a line plot graph for the column ‘model’ and ‘hp’.
#
#         a. Map the ‘model’ column on the x-axis.
#         b. Map the ‘hp’ column on the y-axis.
#         c. Provide the x-axis label as Models of the cars.
#         d. Provide the y-axis label as Horse-Power of Cars.
#         e. Set the title as Model Names vs HorsePower.

# %%
x = cars['model']       #2.a
y = cars['hp']          #2.b

plt.plot(x,y)
plt.xlabel('Models of the cars')             #2.c
plt.ylabel('Horse-Power of Cars')            #2.d
plt.title('Model Names vs HorsePower')       #2.e
plt.show()

# %% [markdown]
# 3. Generate a bar plot graph for the columns ‘carbs’ and ‘gear’.
#
#         a. Map the ‘carbs’ onto the x-axis.
#         b. Map the ‘gear’ onto the y-axis.
#         c. Provide the x-axis label as Number of carburetors.
#         d. Provide the y-axis label as Number of forward gears.
#         e. Set the title as carbs vs gear.

# %%
x = cars['carb']         #1.a
y = cars['gear']         #1.b


plt.bar(x,y)
plt.xlabel('Number of carburetors')         #1.c
plt.ylabel('Horse-Power of Cars')           #1.d
plt.title('Number of forward gears')        #1.e
plt.show()

# %% [markdown]
# 4. Plot a histogram for the column ‘wt’.
#
#         a. Map the ‘wt’ onto the x-axis.
#         b. Provide the x-axis label as ‘weight of the cars’.
#         c. Provide the y-axis label as ‘Count’
#         d. Set the number of bins as 30.
#         e. Set the title as ‘Histogram for the weight values'

# %%
plt.hist(cars['wt'], bins=30)                    #1.a, #1.d
plt.xlabel('weight of the cars')                 #1.b
plt.ylabel('Count')                              #1.c
plt.title('Histogram for the weight values')     #1.e
plt.show()

# %% [markdown]
# 5. Plot a pie chart for columns: ‘cyl’ and ‘model’ form the mtcars.csv data frame.

# %%
cyl = cars['cyl']
model = cars['model']

fig = plt.figure(figsize =(10, 10))
plt.pie(cyl, labels = model)
plt.show()

# %% [markdown]
# 6. Plot the area chart for the colmns: ‘am’ and ‘carb’.
#
#         a. Set the ‘am’ on the x-axis.
#         b. Set the ‘carb’ on the y-axis.
#         c. Provide the x-axis label as Transmission.
#         d. Provide the y-axis labe as Number of carburetors.
#         e. Provide the title as Transmission vs Number of carburetors.

# %%
x = cars['am']
y = cars['carb']

plt.stackplot(x,y)
plt.xlabel('Transmission')
plt.ylabel('Number of carburetors')
plt.title('Transmission vs Number of carburetors')
plt.show()

# %% [markdown]
# 7. Load cars data as dataframe using pandas and create a bar plot between number of cylinders and frequency of cars with that many number of cylinders.
#
#     - Set xlabel as Number of cylinders.
#     - Set ylabel as Frequency of cars.
#      - Draw a bar plot.2.

# %%
cars.head()
# Out:
#    S.No              model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am
# 0     1          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1  \
# 1     2      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2     3         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3     4     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     5  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
#
#    gear  carb
# 0     4     4
# 1     4     4
# 2     4     1
# 3     3     1
# 4     3     2

# %%
cyl_frequency = cars['cyl'].value_counts()
cyl_frequency
# Out:
# cyl
# 8    14
# 4    11
# 6     7
# Name: count, dtype: int64

# %%
cyl_frequency.index
# Out:
# Index([8, 4, 6], dtype='int64', name='cyl')

# %%
cyl_frequency.values
# Out:
# array([14, 11,  7], dtype=int64)

# %%
x = cyl_frequency.index
y = cyl_frequency.values

plt.bar(x, y)
plt.xlabel('Number of cylinders.')
plt.ylabel('Frequency of cars')
plt.show()

# %% [markdown]
# 8. Write code to load data from cars and print a bar graph of count of columns with null values.

# %%
null = cars.isnull().sum()
null
# Out:
# S.No     0
# model    0
# mpg      0
# cyl      0
# disp     0
# hp       0
# drat     0
# wt       0
# qsec     3
# vs       0
# am       0
# gear     0
# carb     0
# dtype: int64

# %%
null_col = null[null>0]
null_col
# Out:
# qsec    3
# dtype: int64

# %%
plt.bar(null_col.index, null_col.values)
plt.xlabel('Columns')
plt.ylabel('Count of Null Values')
plt.title('Count of Null Values in Columns')

plt.show()

# %% [markdown]
# 9. Use the 'mpg' (Miles Per Gallon column) and draw a histogram
#
#         i. Set xlabel: Miles per gallon
#         ii. Set ylabel: Frequency
#         iii. Set title as Miles Per Gallon Histogram
#         iv. Use mpg column to generate a histogram

# %%
plt.hist(cars['mpg'])                    
plt.xlabel('Miles per gallon')                
plt.ylabel('Frequency')                             
plt.title('Miles Per Gallon Histogram')     
plt.show()

# %% [markdown]
# 10. Draw a boxplot on the card dataframes hp column
#
#         i. Set xlabel: Car Horsepower
#         ii. Set title as Boxplot for car horsepower
#         iii. Use hp column to generate a boxplot

# %%
plt.boxplot(cars['hp'])
plt.title('Boxplot for car horsepower')
plt.show()

# %% [markdown]
# #### Churn dataset
# 11. Build a bar-plot for the ‘Contract’ column
#
#         a. Set the x-axis label to be ‘Contract Type of customer’
#         b. Set the y-axis label to be ‘Count’
#         c. Set the title of the plot to be ‘Distribution of Contract’
#         d. Assign ‘orange’ color to all the bars

# %%
churn = pd.read_csv('customer_churn.csv')
churn.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService
# 0  7590-VHVEG  Female              0     Yes         No       1           No  \
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection
# 0  No phone service             DSL             No  ...               No  \
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
churn['Contract'].value_counts()
# Out:
# Contract
# Month-to-month    3875
# Two year          1695
# One year          1473
# Name: count, dtype: int64

# %%
x = churn['Contract'].value_counts().index
y = churn['Contract'].value_counts().values

plt.bar(x,y, color='orange')                    #1.d
plt.xlabel('Contract Type of customer')         #1.a
plt.ylabel('Count')                             #1.b
plt.title('Distribution of Contract')           #1.c
plt.show()

# %% [markdown]
# 12. Sam has to build a histogram for the ‘MonthlyCharges’ column
#
#         a. Set the x-axis label to be ‘Monthly Charges Incurred’
#         b. Set the y-axis label to be ‘Count’
#         c. Set the title of the plot to be ‘Distribution of Monthly Charges’
#         d. Assign ‘forestgreen’ color to the bins

# %%
plt.hist(churn['MonthlyCharges'], color='forestgreen')  #2.d
plt.xlabel('Monthly Charges Incurred')                  #2.a
plt.ylabel('Count')                                     #2.b
plt.title('Distribution of Monthly Charges')            #2.c

plt.show()

# %% [markdown]
# 13. Sam has to build a scatter-plot between ‘TotalCharges’ & ‘tenure’. ‘TotalCharges’ should be on the y-axis and ‘tenure’ should be on the x-axis
#
#         a. Set the x-axis label to be ‘Tenure of the customer’
#         b. Set the y-axis label to be ‘Total chargesIncurred’
#         c. Set the title of the plot to be ‘Total Charges vs Tenure’
#         d. Assign ‘indigo’ color to the points

# %%
x = churn['tenure']
y = churn['TotalCharges']

plt.scatter(x,y, color='indigo')
plt.xlabel('Tenure of the customer')
plt.ylabel('Total charges Incurred')
plt.title('Total Charges vs Tenure')

plt.show()

# %% [markdown]
# 14. Sam has to build a box-plot between ‘MonthlyCharges’ & ‘PaymentMethod’.
#
#         ‘MonthlyCharges’ should be on the y-axis and ‘PaymentMethod’ should be on the x-axis.
#         a. Set the x-axis label to be ‘Payment Method of customer’
#         b. Set the y-axis label to be ‘Monthly ChargesIncurred’
#         c. Set the title of plot to be ‘Monthly Charges vs. Payment Method’
#         d. Assign ‘olive’ color to the box-plots

# %%
import seaborn as sns

# %%
plt.figure(figsize=(10,7))

sns.boxplot(x='PaymentMethod', y='MonthlyCharges', data=churn, showmeans= True, color="olive")

plt.xlabel('Payment Method of customer')
plt.ylabel('Monthly Charges Incurred')
plt.title('Monthly Charges vs. Payment Method')

plt.show()
